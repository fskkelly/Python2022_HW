# %% [markdown]
# # 2.1

# %%
print("HAPPY" == "Happy")
# Out:
# False

# %%
4 / 3
# Out:
# 1.3333333333333333

# %%
4 // 3
# Out:
# 1

# %%
2 ** 3 ** 2
# Out:
# 512

# %%
12.3 * 10 % 5
# Out:
# 3.0

# %%
print('a' > 'Z')
# Out:
# True

# %%
print(123 == "123")
# Out:
# False

# %%
print((5 + 3 * 8 < 30) and (3 * 2 == 9))
# Out:
# False

# %%
print("Happ", "New", "Year", end = "!!!")
# Out:
# Happ New Year!!!

# %%
eval("456 - 123 * 2")
# Out:
# 210

# %% [markdown]
# # 2.2

# %%
_ab~c = 0
# Out:
#   File "<ipython-input-27-1c469cc619ed>", line 1
#     _ab~c = 0
#        ^
# SyntaxError: invalid syntax

# %%
as_yt = 0

# %%
5abcde = 0
# Out:
#   File "<ipython-input-25-33f935edb72e>", line 1
#     5abcde = 0
#          ^
# SyntaxError: invalid syntax

# %%
_abs10 = 0

# %%
\nabc = 0
# Out:
#   File "<ipython-input-24-c0a5239470f5>", line 1
#     \nabc = 0
#              ^
# SyntaxError: unexpected character after line continuation character

# %%
$xyz10 = 0
# Out:
#   File "<ipython-input-23-0999c3125aa3>", line 1
#     $xyz10 = 0
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 2.3

# %%
type(False)
# Out:
# bool

# %%
type('a')
# Out:
# str

# %%
type(1.23E-5)
# Out:
# float

# %%
type(1+2j)
# Out:
# complex

# %%
type([1,2,3,4,5])
# Out:
# list

# %%
#2.4
print(80 * 1 * 60 * 60 * 24 * 365.25 / 60 * 72)
# Out:
# 3029529600.0

# %%
#2.5
C = eval(input("Input a temperature."))
F = C * 1.8 + 32
print(C, "°C")
print(F, "°F")
# Out:
# Input a temperature.25
# 25 °C
# 77.0 °F

# %%
#2.6
x = eval(input("How big is your house(坪)?"))
x = x * 3.3058
print(x, "m2")
# Out:
# How big is your house(坪)?100
# 330.58 m2

# %%
#2.7
H = eval(input("Input height(cm)."))
W = eval(input("Input weight(kg)."))
BMI = W / (H / 100) ** 2
print("BMI is ", BMI, ".")
# Out:
# Input height(cm).158
# Input weight(kg).62
# BMI is  24.83576349943919 .

# %%
#2.9
a = eval(input("Input a."))
b = eval(input("Input b."))
c = eval(input("Input c."))
result = (-b + (b ** 2 - 4 * a * c) ** 0.5) / (2 * a)
print(result)
# Out:
# Input a.2
# Input b.5
# Input c.2
# -0.5

# %%
#2.10
a = eval(input("Input a."))
b = eval(input("Input b."))
result = (a ** 2 - b ** 2) / (a + b)
print(result)
# Out:
# Input a.100
# Input b.50
# 50.0
