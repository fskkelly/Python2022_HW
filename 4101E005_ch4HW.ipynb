# %%
#1.3
for i in range(100, 200, 3):
  print(i)
# Out:
# 100
# 103
# 106
# 109
# 112
# 115
# 118
# 121
# 124
# 127
# 130
# 133
# 136
# 139
# 142
# 145
# 148
# 151
# 154
# 157
# 160
# 163
# 166
# 169
# 172
# 175
# 178
# 181
# 184
# 187
# 190
# 193
# 196
# 199

# %%
#1.4
i = 1
while i < 100:
  i = i + 7
  print(i)
# Out:
# 8
# 15
# 22
# 29
# 36
# 43
# 50
# 57
# 64
# 71
# 78
# 85
# 92
# 99
# 106

# %%
#1.6
count = 0
for i in range(100, 10, -3):
  count+=1
print(count)
# Out:
# 30

# %%
#2.1
for i in range(1, 100):
  if i % 13 == 0:
    print(i)
# Out:
# 13
# 26
# 39
# 52
# 65
# 78
# 91

# %%
#2.2
sum = 0
for i in range(1, 9):
  result = (1 / 2) ** i
  sum += result
print(sum)
# Out:
# 0.99609375

# %%
#2.3
sum = 1
for i in range(2, 11):
  result = 1 / i
  sum = sum + result
print(sum)
# Out:
# 2.9289682539682538

# %%
#2.4
x = eval(input("Input $"))
if x <= 520000:
  print("5%")
elif x <= 1170000:
  print("12%")
elif x <= 2350000:
  print("20%")
elif x <= 4400000:
  print("30%")
else:
  print("40%")
# Out:
# Input $4400001
# 40%

# %%
#2.5
count = 0
i = 25000 * 12
while i < 600000:
  i = i * 1.03
  count += 1
print(count)
# Out:
# 24

# %%
#2.6
for i in range(1, 5):
  for j in range(1, 5):
    if i * j < 8:
      continue
    print(i * j)
# Out:
# 8
# 9
# 12
# 8
# 12
# 16
