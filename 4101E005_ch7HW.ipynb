# %% [markdown]
# # 2.1

# %%
fileObject = open("sample1.txt", "a")

fileObject.write("錦瑟\n")
fileObject.write("錦瑟無端五十弦，一弦一柱思華年。\n")
fileObject.write("莊生曉夢迷蝴蝶，望帝春心托杜鵑。\n")
fileObject.write("滄海月明珠有淚，藍田日暖玉生煙。\n")
fileObject.write("此情可待成追憶，只是當時已惘然。")

fileObject.close()

# %%
import os.path

if os.path.isfile("sample2.txt") == False:
  fileObject1 = open("sample1.txt", "r")
  fileObject2 = open("sample2.txt", "w")

  content = fileObject1.read()
  fileObject2.write(content)

  fileObject1.close()
  fileObject2.close()

  print("sample1.txt has been copied to sample2.txt!")

else:
  print("File already exists!")
# Out:
# File already exists!

# %% [markdown]
# #2.2

# %%
import os.path

if os.path.isfile("sample1.txt"):
    fileObject = open("sample1.txt", "r")
    count1 = count2 = 0    

    for line in fileObject:
      count1 += 1
    print(count1, "lines")

    for i in content:
      count2 += 1
    print(count2, "words")

    fileObject.close()
else:
    print("此檔案不存在")
# Out:
# 5 lines
# 70 words
