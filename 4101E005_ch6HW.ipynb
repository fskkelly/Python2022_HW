# %%
#2.1
student1 = {"ID" : "01", "name" : "王小明"}
student1["name"] = "張美美"
student1["國文"] = 90
student1["英文"] = 80
student1["數學"] = 100
del student1["ID"]

student1
# Out:
# {'name': '張美美', '國文': 90, '英文': 80, '數學': 100}

# %%
#2.2
list1 = [5, 10, 15, 20]

print(list1 * 2)

print(100 in list1)

print(list1.index(15))

print([i ** 2 for i in list1])

print([i ** 5 for i in list1 if i < 20])

list1.reverse()
list1
# Out:
# [5, 10, 15, 20, 5, 10, 15, 20]
# False
# 2
# [25, 100, 225, 400]
# [3125, 100000, 759375]
# [20, 15, 10, 5]

# %%
#2.3
def find(*list1):
  value = eval(input("Input value you want to find."))
  if value in list1:
    print("value = ", value, "\nindex = ", list1.index(value))
  else:
    print(-1)

find(54, 2, 40, 22, 17, 22, 60, 35)
# Out:
# Input value you want to find.22
# value =  22
# index =  3

# %%
#2.5
S1 = {1, 8, 9, 7, 6}
S2 = {2, 5, 6, 8, 9}

print(len(S1))

print(S1.issubset(S2))

S3 = S1 | S2
print(S3)

S4 = S1 & S2
print(S4)

S5 = S1 - S2
print(S5)

print(sum(S1))
# Out:
# 5
# False
# {1, 2, 5, 6, 7, 8, 9}
# {8, 9, 6}
# {1, 7}
# 31

# %%
#2.6
str1 = list(input("Input a string."))
str1.reverse()
str1
# Out:
# Input a string.qwertyuiop
# ['p', 'o', 'i', 'u', 'y', 't', 'r', 'e', 'w', 'q']
